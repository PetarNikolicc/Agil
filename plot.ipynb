# %%
# Initial setup
import pandas as pd

print("Setup complete!")
# Out:
# Setup complete!

# %%
# Kodblock för att förstå och sen kunna filtrera datasettet.
df = pd.read_csv("RAW_recipes.csv")
df.head(10)
df.describe()
df.columns
# df.shape
# df.head(5)
# Out:
# Index(['name', 'id', 'minutes', 'contributor_id', 'submitted', 'tags',
#        'nutrition', 'n_steps', 'steps', 'description', 'ingredients',
#        'n_ingredients'],
#       dtype='object')

# %%
# Rensar upp i datasettet.
columns_to_use = ['id', 'name', 'minutes', 'n_steps', 'steps', 'ingredients', 'n_ingredients']

df = pd.read_csv("RAW_recipes.csv", usecols=columns_to_use, skipinitialspace=True)
df = df.dropna()
df['name'].str.strip()

# df.to_csv("Data.csv")

df2 = df.head(10)

df2.to_csv("data2.csv")
df.head(11)
# Out:
#                                           name      id  minutes  n_steps  \
# 0   arriba   baked winter squash mexican style  137739       55       11
# 1             a bit different  breakfast pizza   31490       30        9
# 2                    all in the kitchen  chili  112140      130        6
# 3                           alouette  potatoes   59389       45       11
# 4           amish  tomato ketchup  for canning   44061      190        5
# 5                      apple a day  milk shake    5289        0        4
# 6                        aww  marinated olives   25274       15        4
# 7               backyard style  barbecued ribs   67888      120       10
# 8                     bananas 4 ice cream  pie   70971      180        8
# 9                      beat this  banana bread   75452       70       12
# 10                 berry  good sandwich spread  109439        5        2
#
#                                                 steps  \
# ...

# %%
# Skapar en databas av den nya .csv filen.
import sqlite3

conn = sqlite3.connect('Database.db')

df.to_sql('Data_table', conn, if_exists='replace', index=False)

conn.close()

# %%
print(len(df))

df2.head(100)
# Out:
# 231636
#                                          name      id  minutes  n_steps  \
# 0  arriba   baked winter squash mexican style  137739       55       11
# 1            a bit different  breakfast pizza   31490       30        9
# 2                   all in the kitchen  chili  112140      130        6
# 3                          alouette  potatoes   59389       45       11
# 4          amish  tomato ketchup  for canning   44061      190        5
# 5                     apple a day  milk shake    5289        0        4
# 6                       aww  marinated olives   25274       15        4
# 7              backyard style  barbecued ribs   67888      120       10
# 8                    bananas 4 ice cream  pie   70971      180        8
# 9                     beat this  banana bread   75452       70       12
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# ...
